# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
df = pd.read_csv('hotel_bookings.csv')
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Data Understanding

# %%
def data_understanding(df):
        print(f"{'*' * 50} Data Information {'*' * 68}")
        display(df.info())
        print(f"\n{'*' * 50} Checking For Duplicate Values {'*' * 55}")
        display(df.duplicated().sum())
        print(f"\n{'*' * 50} Description of Numerical Columns {'*' * 52}")
        display(df.describe())
        print(f"\n{'*' * 50} Description of Categorical Columns {'*' * 50}")
        display(df.describe(include = 'object'))
        print(f"\n{'*' * 50} DataFrame Summary {'*' * 50}")
        display(df.head())
    
data_understanding(df)
# Out:
# ************************************************** Data Information ********************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
# ...

# %% [markdown]
# ### Data Cleaning

# %%
def cleaned_data(df):
    # Handling missing values
    df['country'].fillna('Unknown', inplace = True)
    df['agent'].fillna(df['agent'].mean().round(1), inplace = True)
    df['company'].fillna(df['company'].mean(), inplace = True)
    df['children'].fillna(df['children'].median(), inplace = True)

    # Drop Duplicates
    df.drop_duplicates(inplace = True)

    # date to Datetime
    df['reservation_status_date']= pd.to_datetime(df['reservation_status_date'])

    # Total People in Booking
    df['total_people'] = df['adults'] + df['children'] + df['babies']

    # Total Stay Duration
    df['total_stay'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']

    return df

# %% [markdown]
# ### Exploratory Data Analysis

# %%
def visualizations(df):
    # What proportion of bookings were cancelled vs. not cancelled?
    plt.figure(figsize=(6,6))
    sns.countplot(data=df, x='is_canceled', palette='Set2')
    plt.title('Booking Status Distribution')
    plt.xlabel('Booking Status')
    plt.ylabel('Count')
    plt.show()

    # Which hotel type has higher cancellations?
    plt.figure(figsize=(8,6))
    sns.countplot(data=df, x='hotel', hue='is_canceled', palette='Set1')
    plt.title('Cancellations by Hotel Type')
    plt.xlabel('Hotel Type')
    plt.ylabel('Count')
    plt.legend(['Not Canceled', 'Canceled'])
    plt.show()

    # Do longer lead times increase the chance of cancellation?
    plt.figure(figsize=(8,6))
    sns.boxplot(data=df, x='is_canceled', y='lead_time', palette='Set3')
    plt.title('Lead Time vs. Cancellation')
    plt.xlabel('Booking Status')
    plt.ylabel('Lead Time (Days)')
    plt.show()

    # Are cancellations seasonal?
    monthly_data = df.groupby(['arrival_date_month', 'is_canceled']).size().unstack()

    # Sort months correctly
    months_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
                    'August', 'September', 'October', 'November', 'December']
    monthly_data = monthly_data.reindex(months_order)
    
    monthly_data.plot(kind='bar', stacked=True, figsize=(12,6), colormap='Paired')
    
    plt.title('Monthly Booking and Cancellation Trends')
    plt.xlabel('Month')
    plt.ylabel('Number of Bookings')
    plt.xticks(rotation=45)
    plt.show()

    # Where do most customers come from?
    top_countries = df['country'].value_counts().head(10)

    plt.figure(figsize=(10,6))
    sns.barplot(x=top_countries.index, y=top_countries.values, palette='coolwarm')
    
    plt.title('Top 10 Customer Countries')
    plt.xlabel('Country')
    plt.ylabel('Number of Bookings')
    plt.xticks(rotation=45)
    plt.show()

    # Which market segments have the highest cancellations?
    plt.figure(figsize=(10,6))
    sns.countplot(data=df, x='market_segment', hue='is_canceled', palette='viridis')
    
    plt.title('Market Segment vs. Cancellations')
    plt.xlabel('Market Segment')
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.legend(['Not Canceled', 'Canceled'])
    plt.show()

    # Which numerical features are most related to cancellations?
    plt.figure(figsize=(12,8))
    sns.heatmap(df.corr(), cmap='coolwarm', annot=True, fmt='.2f')
    
    plt.title('Correlation Heatmap')
    plt.show()

# %%
visualizations(df)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20580\2817720739.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='is_canceled', palette='Set2')
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20580\2817720739.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='is_canceled', y='lead_time', palette='Set3')
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20580\2817720739.py:47: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_countries.index, y=top_countries.values, palette='coolwarm')
# ...

# %%
def insights_suggestions():
    print(f"{'*' * 50} Insights {'*' * 50}")

    print(
        '''
    1. Booking Status Distribution
        - A significant portion of hotel bookings are canceled.
        - This indicates a potential need to review booking policies and prepayment requirements.

    2. Hotel Type Cancellations
        - City hotels experience a higher rate of cancellations compared to resort hotels.
        - Customers booking resort hotels may have higher commitment levels or face stricter cancellation policies.

    3. Lead Time Impact
        - Longer lead times are strongly associated with higher cancellation rates.
        - Bookings made far in advance are more likely to get canceled, possibly due to changing travel plans.

    4. Seasonal Trends
        - Cancellation rates fluctuate throughout the year, with noticeable peaks in certain months.
        - High cancellation seasons may align with peak travel times, requiring careful capacity planning.

    5. Country-wise Trends
        - Bookings are concentrated from a small number of countries.
        - Customers from specific countries may have higher cancellation tendencies, indicating a possible cultural or policy-related factor.

    6. Market Segment Insights
        - Online bookings and transient customers have the highest cancellation rates.
        - Corporate and direct bookings show significantly lower cancellations, suggesting more reliable customer sources.

    7. Correlation Heatmap
        - Lead time, previous cancellations, and deposit type show the strongest correlation with booking cancellations.
        - Variables like special requests and total stay length have minimal direct correlation with cancellations.
        '''
    )

    print(f"{'*' * 50} Suggestions {'*' * 50}")

    print(
        '''
    1. Strengthen Cancellation Policies for Long Lead Times
        - Consider stricter cancellation terms for bookings made well in advance.
        - Implement incremental penalties based on proximity to check-in date.

    2. Focus on Reliable Customer Segments
        - Develop targeted loyalty programs for corporate and direct customers to encourage repeat bookings.
        - Consider offering exclusive perks to market segments with historically lower cancellation rates.

    3. Improve Booking Forecasting in Peak Seasons
        - Monitor monthly cancellation trends and adjust overbooking strategies accordingly.
        - High cancellation months should trigger tighter revenue management.

    4. Implement Targeted Communication
        - Send personalized reminders and flexible upgrade offers to customers with long lead times to reduce the likelihood of cancellations.

    5. Country-Specific Strategies
        - Analyze high-risk countries further to understand potential cultural or economic drivers.
        - Consider country-specific booking terms or deposit policies.

    6. Real-Time Dashboard Monitoring
        - Set up a cancellation tracking dashboard to identify emerging patterns quickly.
        - This will help the hotel proactively manage sudden surges in cancellations.

    7. Special Requests as a Retention Signal
        - Encourage and prioritize handling of special requests as it may indicate customer commitment.
        - Customers with special requests can be targeted with personalized retention offers.
        '''
    )

# %%
insights_suggestions()
# Out:
# ************************************************** Insights **************************************************
#
#     1. Booking Status Distribution
#         - A significant portion of hotel bookings are canceled.
#         - This indicates a potential need to review booking policies and prepayment requirements.
#
#     2. Hotel Type Cancellations
#         - City hotels experience a higher rate of cancellations compared to resort hotels.
#         - Customers booking resort hotels may have higher commitment levels or face stricter cancellation policies.
#
#     3. Lead Time Impact
#         - Longer lead times are strongly associated with higher cancellation rates.
#         - Bookings made far in advance are more likely to get canceled, possibly due to changing travel plans.
#
#     4. Seasonal Trends
#         - Cancellation rates fluctuate throughout the year, with noticeable peaks in certain months.
# ...
